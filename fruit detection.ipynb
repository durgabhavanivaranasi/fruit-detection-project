# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
fruits=pd.read_csv(r"C:\Users\DURGA BHAVANI\Downloads\fruits1.csv")
print(fruits)
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0             1      apple  granny_smith   192    8.4     7.3         0.55
# 1             1      apple  granny_smith   180    8.0     6.8         0.59
# 2             1      apple  granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin      mandarin    86    6.2     4.7         0.80
# 4             2   mandarin      mandarin    84    6.0     4.6         0.79
# ..          ...        ...           ...   ...    ...     ...          ...
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70
# 59            5          0             0     0    0.0     0.0         0.00
# 60            6          0             0     0    0.0     0.0         0.00
# 61            7          0             0     0    0.0     0.0         0.00
#
# [62 rows x 7 columns]

# %%
fruits.loc[:58,"fruit_subtype"]
# Out:
# 0         granny_smith
# 1         granny_smith
# 2         granny_smith
# 3             mandarin
# 4             mandarin
# 5             mandarin
# 6             mandarin
# 7             mandarin
# 8             braeburn
# 9             braeburn
# 10            braeburn
# 11            braeburn
# 12            braeburn
# 13    golden_delicious
# 14    golden_delicious
# 15    golden_delicious
# 16    golden_delicious
# 17    golden_delicious
# 18         cripps_pink
# 19         cripps_pink
# 20         cripps_pink
# 21         cripps_pink
# 22         cripps_pink
# 23         cripps_pink
# 24       spanish_jumbo
# 25       spanish_jumbo
# 26       spanish_jumbo
# 27    selected_seconds
# 28    selected_seconds
# 29    selected_seconds
# 30    selected_seconds
# 31    selected_seconds
# 32    selected_seconds
# 33        turkey_navel
# 34        turkey_navel
# 35        turkey_navel
# 36        turkey_navel
# 37        turkey_navel
# 38        turkey_navel
# 39        turkey_navel
# ...

# %%
fruits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    62 non-null     int64
#  1   fruit_name     62 non-null     object
#  2   fruit_subtype  62 non-null     object
#  3   mass           62 non-null     int64
#  4   width          62 non-null     float64
#  5   height         62 non-null     float64
#  6   color_score    62 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.5+ KB

# %%
fruits.shape
# Out:
# (62, 7)

# %%
fruits.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
predict = dict(zip(fruits.fruit_label.unique(), fruits.fruit_name.unique()))   
predict
# Out:
# {1: 'apple', 2: 'mandarin', 3: 'orange', 4: 'lemon', 5: '0'}

# %%
fruits.columns
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
fruits['fruit_name'].value_counts()
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# 0            3
# Name: fruit_name, dtype: int64

# %%
apple_data=fruits[fruits['fruit_name']=='apple']
orange_data=fruits[fruits['fruit_name']=='orange']
lemon_data=fruits[fruits['fruit_name']=='lemon']
mandarin_data=fruits[fruits['fruit_name']=='mandarin']

# %%
apple_data
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# 11            1      apple          braeburn   172    7.1     7.6         0.92
# 12            1      apple          braeburn   154    7.0     7.1         0.88
# 13            1      apple  golden_delicious   164    7.3     7.7         0.70
# 14            1      apple  golden_delicious   152    7.6     7.3         0.69
# 15            1      apple  golden_delicious   156    7.7     7.1         0.69
# ...

# %%
fruits.dropna()
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0             1      apple  granny_smith   192    8.4     7.3         0.55
# 1             1      apple  granny_smith   180    8.0     6.8         0.59
# 2             1      apple  granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin      mandarin    86    6.2     4.7         0.80
# 4             2   mandarin      mandarin    84    6.0     4.6         0.79
# ..          ...        ...           ...   ...    ...     ...          ...
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70
# 59            5          0             0     0    0.0     0.0         0.00
# 60            6          0             0     0    0.0     0.0         0.00
# 61            7          0             0     0    0.0     0.0         0.00
#
# [62 rows x 7 columns]

# %%
fruits.fillna(0)
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0             1      apple  granny_smith   192    8.4     7.3         0.55
# 1             1      apple  granny_smith   180    8.0     6.8         0.59
# 2             1      apple  granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin      mandarin    86    6.2     4.7         0.80
# 4             2   mandarin      mandarin    84    6.0     4.6         0.79
# ..          ...        ...           ...   ...    ...     ...          ...
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70
# 59            5          0             0     0    0.0     0.0         0.00
# 60            6          0             0     0    0.0     0.0         0.00
# 61            7          0             0     0    0.0     0.0         0.00
#
# [62 rows x 7 columns]

# %%
apple_data.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 8            1      apple      braeburn   178    7.1     7.8         0.92
# 9            1      apple      braeburn   172    7.4     7.0         0.89

# %%
mandarin_data
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81
# 7            2   mandarin      mandarin    76    5.8     4.0         0.81

# %%
mandarin_data.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81
# 7            2   mandarin      mandarin    76    5.8     4.0         0.81

# %%
orange_data
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 24            3     orange     spanish_jumbo   342    9.0     9.4         0.75
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# ...

# %%
orange_data.head()
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 24            3     orange     spanish_jumbo   342    9.0     9.4         0.75
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72

# %%
lemon_data
# Out:
#     fruit_label fruit_name   fruit_subtype  mass  width  height  color_score
# 43            4      lemon  spanish_belsan   194    7.2    10.3         0.70
# 44            4      lemon  spanish_belsan   200    7.3    10.5         0.72
# 45            4      lemon  spanish_belsan   186    7.2     9.2         0.72
# 46            4      lemon  spanish_belsan   216    7.3    10.2         0.71
# 47            4      lemon  spanish_belsan   196    7.3     9.7         0.72
# 48            4      lemon  spanish_belsan   174    7.3    10.1         0.72
# 49            4      lemon         unknown   132    5.8     8.7         0.73
# 50            4      lemon         unknown   130    6.0     8.2         0.71
# 51            4      lemon         unknown   116    6.0     7.5         0.72
# 52            4      lemon         unknown   118    5.9     8.0         0.72
# 53            4      lemon         unknown   120    6.0     8.4         0.74
# ...

# %%
lemon_data.head()
# Out:
#     fruit_label fruit_name   fruit_subtype  mass  width  height  color_score
# 43            4      lemon  spanish_belsan   194    7.2    10.3         0.70
# 44            4      lemon  spanish_belsan   200    7.3    10.5         0.72
# 45            4      lemon  spanish_belsan   186    7.2     9.2         0.72
# 46            4      lemon  spanish_belsan   216    7.3    10.2         0.71
# 47            4      lemon  spanish_belsan   196    7.3     9.7         0.72

# %%
import seaborn as sns
sns.lmplot(x = 'height', y = 'width', hue = 'fruit_name', data = fruits)

# %%
sns.lmplot(x = 'mass', y = 'color_score', hue = 'fruit_name', data =fruits)

# %%
from sklearn.model_selection import train_test_split
x=fruits[['color','width','height']]
y=fruits['fruit_label']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x=fruits[['color','width','height']]
#       3 y=fruits['fruit_label']
#       4 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 20)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
